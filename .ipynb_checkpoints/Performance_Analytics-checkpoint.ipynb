# %%
import sqlite3
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import linregress

sns.set_style("whitegrid")

# %%
conn = sqlite3.connect("bluestock_mf.db")

# %% [markdown]
# # Check Tables

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table'
""", conn)
# Out:
#                 name
# 0           dim_fund
# 1           fact_nav
# 2  fact_transactions
# 3   fact_performance
# 4           fact_aum

# %% [markdown]
# # Load NAV Data

# %%
query = """
SELECT
amfi_code,
date,
nav
FROM fact_nav
"""

nav_df = pd.read_sql(query, conn)

nav_df['date'] = pd.to_datetime(nav_df['date'])

nav_df.head()
# Out:
#    amfi_code       date       nav
# 0     100016 2022-01-03  520.4608
# 1     100016 2022-01-04  515.0971
# 2     100016 2022-01-05  521.7239
# 3     100016 2022-01-06  515.7880
# 4     100016 2022-01-07  515.1639

# %% [markdown]
# # Compute Daily Returns

# %%
nav_df = nav_df.sort_values(
    ['amfi_code','date']
)

nav_df['daily_return'] = (
    nav_df.groupby('amfi_code')['nav']
    .pct_change()
)

nav_df.head()
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2022-01-03  520.4608           NaN
# 1     100016 2022-01-04  515.0971     -0.010306
# 2     100016 2022-01-05  521.7239      0.012865
# 3     100016 2022-01-06  515.7880     -0.011377
# 4     100016 2022-01-07  515.1639     -0.001210

# %% [markdown]
# # Daily Return Distribution Chart

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    nav_df['daily_return'].dropna(),
    bins=100,
    kde=True
)

plt.title("Daily Return Distribution")

plt.savefig(
    "daily_return_distribution.png"
)

plt.show()

# %% [markdown]
# # CAGR Calculation

# %%
cagr_results = []

for fund in nav_df['amfi_code'].unique():

    temp = nav_df[
        nav_df['amfi_code']==fund
    ]

    start_nav = temp.iloc[0]['nav']

    end_nav = temp.iloc[-1]['nav']

    years = (
        temp['date'].max()
        -
        temp['date'].min()
    ).days/365

    cagr = (
        (end_nav/start_nav)
        **
        (1/years)
        -1
    )

    cagr_results.append(
        [fund,cagr]
    )

cagr_df = pd.DataFrame(
    cagr_results,
    columns=[
        'amfi_code',
        'cagr'
    ]
)

cagr_df.head()
# Out:
#    amfi_code      cagr
# 0     100016  0.026352
# 1     100025  0.044551
# 2     100033  0.300997
# 3     101206  0.235205
# 4     101207  0.079331

# %% [markdown]
# # Save CAGR Table

# %%
cagr_df.to_csv(
    "cagr_table.csv",
    index=False
)

# %% [markdown]
# # Sharpe Ratio

# %%
rf = 0.065

sharpe_list = []

for fund in nav_df['amfi_code'].unique():

    temp = nav_df[
        nav_df['amfi_code']==fund
    ]

    annual_return = (
        temp['daily_return'].mean()
        *252
    )

    volatility = (
        temp['daily_return'].std()
        *np.sqrt(252)
    )

    sharpe = (
        annual_return-rf
    ) / volatility

    sharpe_list.append(
        [fund,sharpe]
    )

sharpe_df = pd.DataFrame(
    sharpe_list,
    columns=[
        'amfi_code',
        'sharpe_ratio'
    ]
)

sharpe_df.sort_values(
    'sharpe_ratio',
    ascending=False
).head()
# Out:
#     amfi_code  sharpe_ratio
# 34     148567      1.448291
# 30     120843      1.306744
# 36     148569      1.234930
# 19     119551      1.208267
# 25     120505      1.180101

# %% [markdown]
# # Export Sharpe Rankings

# %%
sharpe_df.to_csv(
    "sharpe_ratio_rankings.csv",
    index=False
)

# %% [markdown]
# # Sortino Ratio

# %%
sortino_list = []

for fund in nav_df['amfi_code'].unique():

    temp = nav_df[
        nav_df['amfi_code']==fund
    ]

    downside = temp[
        temp['daily_return'] < 0
    ]['daily_return']

    downside_std = (
        downside.std()
        *np.sqrt(252)
    )

    annual_return = (
        temp['daily_return'].mean()
        *252
    )

    sortino = (
        annual_return-rf
    ) / downside_std

    sortino_list.append(
        [fund,sortino]
    )

sortino_df = pd.DataFrame(
    sortino_list,
    columns=[
        'amfi_code',
        'sortino_ratio'
    ]
)

sortino_df.head()
# Out:
#    amfi_code  sortino_ratio
# 0     100016      -0.351047
# 1     100025      -0.941821
# 2     100033       1.829134
# 3     101206       1.799563
# 4     101207       0.276644

# %% [markdown]
# # Export Sortino

# %%
sortino_df.to_csv(
    "sortino_ratio_rankings.csv",
    index=False
)

# %% [markdown]
# # Maximum Drawdown

# %%
dd_results = []

for fund in nav_df['amfi_code'].unique():

    temp = nav_df[
        nav_df['amfi_code']==fund
    ].copy()

    temp['running_max'] = (
        temp['nav'].cummax()
    )

    temp['drawdown'] = (
        temp['nav']
        /
        temp['running_max']
        -1
    )

    max_dd = (
        temp['drawdown'].min()
    )

    dd_results.append(
        [fund,max_dd]
    )

dd_df = pd.DataFrame(
    dd_results,
    columns=[
        'amfi_code',
        'max_drawdown'
    ]
)

dd_df.head()
# Out:
#    amfi_code  max_drawdown
# 0     100016     -0.247344
# 1     100025     -0.043083
# 2     100033     -0.162172
# 3     101206     -0.112916
# 4     101207     -0.354469

# %% [markdown]
# # Check Performance Table Structure

# %%
pd.read_sql("""
PRAGMA table_info(fact_performance)
""", conn)
# Out:
#     cid                name    type  notnull dflt_value  pk
# 0     0           amfi_code  BIGINT        0       None   0
# 1     1         scheme_name    TEXT        0       None   0
# 2     2          fund_house    TEXT        0       None   0
# 3     3            category    TEXT        0       None   0
# 4     4                plan    TEXT        0       None   0
# 5     5      return_1yr_pct   FLOAT        0       None   0
# 6     6      return_3yr_pct   FLOAT        0       None   0
# 7     7      return_5yr_pct   FLOAT        0       None   0
# 8     8   benchmark_3yr_pct   FLOAT        0       None   0
# 9     9               alpha   FLOAT        0       None   0
# 10   10                beta   FLOAT        0       None   0
# 11   11        sharpe_ratio   FLOAT        0       None   0
# 12   12       sortino_ratio   FLOAT        0       None   0
# 13   13     std_dev_ann_pct   FLOAT        0       None   0
# 14   14    max_drawdown_pct   FLOAT        0       None   0
# ...

# %% [markdown]
# # Load Performance Data

# %%
performance = pd.read_sql("""
SELECT *
FROM fact_performance
""", conn)

performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %% [markdown]
# # Alpha-Beta Table

# %%
alpha_beta = performance[
    [
        'amfi_code',
        'scheme_name',
        'alpha',
        'beta'
    ]
]

alpha_beta.head()
# Out:
#    amfi_code                                   scheme_name  alpha  beta
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth   0.87  0.89
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth   1.78  0.87
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth   1.23  0.89
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth   1.13  1.04
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth   1.60  0.22

# %% [markdown]
# # Export alpha_beta.csv

# %%
alpha_beta.to_csv(
    "alpha_beta.csv",
    index=False
)

# %% [markdown]
# # Fund Scorecard

# %% [markdown]
# 30% × 3yr return rank
# 25% × Sharpe rank
# 20% × Alpha rank
# 15% × Expense Ratio rank (inverse)
# 10% × Max Drawdown rank (inverse)

# %%
scorecard = performance.copy()

# %% [markdown]
# # Rank 3-Year Returns

# %%
scorecard['return_rank'] = (
    scorecard['return_3yr_pct']
    .rank(pct=True)
)

# %% [markdown]
# # Rank Sharpe

# %%
scorecard['sharpe_rank'] = (
    scorecard['sharpe_ratio']
    .rank(pct=True)
)

# %% [markdown]
# # Rank Alpha

# %%
scorecard['alpha_rank'] = (
    scorecard['alpha']
    .rank(pct=True)
)

# %% [markdown]
# # Expense Ratio (Lower Better)

# %%
scorecard['expense_rank'] = (
    scorecard['expense_ratio_pct']
    .rank(
        pct=True,
        ascending=False
    )
)

# %% [markdown]
# # Drawdown (Lower Better)

# %%
scorecard['dd_rank'] = (
    scorecard['max_drawdown_pct']
    .rank(
        pct=True,
        ascending=False
    )
)

# %% [markdown]
# # Composite Score

# %%
scorecard['fund_score'] = (

    scorecard['return_rank']*30 +

    scorecard['sharpe_rank']*25 +

    scorecard['alpha_rank']*20 +

    scorecard['expense_rank']*15 +

    scorecard['dd_rank']*10

)

# %% [markdown]
# # Top Funds

# %%
scorecard[
    [
        'scheme_name',
        'fund_score'
    ]
].sort_values(
    'fund_score',
    ascending=False
).head(10)
# Out:
#                                       scheme_name  fund_score
# 3       SBI Small Cap Fund - Direct Plan - Growth     72.7500
# 22         Kotak Flexicap Fund - Regular - Growth     71.5000
# 21  Kotak Emerging Equity Fund - Regular - Growth     70.5000
# 29         ABSL Small Cap Fund - Regular - Growth     68.2500
# 2      SBI Small Cap Fund - Regular Plan - Growth     64.3750
# 34  Mirae Asset Large Cap Fund - Regular - Growth     63.9375
# 9    HDFC Short Term Debt Fund - Regular - Growth     63.0000
# 14       ICICI Pru Liquid Fund - Regular - Growth     61.7500
# 12       ICICI Pru Midcap Fund - Regular - Growth     61.0000
# 11      ICICI Pru Bluechip Fund - Direct - Growth     59.6250

# %% [markdown]
# # Export Fund Scorecard

# %%
scorecard.to_csv(
    "fund_scorecard.csv",
    index=False
)

# %% [markdown]
# # Top 10 Fund Score Chart

# %%
top10 = scorecard.sort_values(
    'fund_score',
    ascending=False
).head(10)

plt.figure(figsize=(12,6))

sns.barplot(
    data=top10,
    x='fund_score',
    y='scheme_name'
)

plt.title(
    "Top 10 Fund Scorecard Rankings"
)

plt.savefig(
    "fund_scorecard.png"
)

plt.show()

# %% [markdown]
# # Benchmark Comparison Chart

# %%
top5 = scorecard.sort_values(
    'fund_score',
    ascending=False
).head(5)

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top5,
    x='scheme_name',
    y='return_3yr_pct'
)

plt.xticks(rotation=90)

plt.axhline(
    y=top5['benchmark_3yr_pct'].mean(),
    color='red',
    linestyle='--',
    label='Benchmark'
)

plt.legend()

plt.title(
    "Top 5 Funds vs Benchmark"
)

plt.savefig(
    "benchmark_comparison.png"
)

plt.show()

# %% [markdown]
# # Markdown Insights

# %% [markdown]
# 1. Small-cap funds dominate top performance rankings.
#
# 2. Top-ranked funds consistently outperform benchmark returns.
#
# 3. Higher Sharpe ratios indicate superior risk-adjusted performance.
#
# 4. Lower expense ratio funds generally receive better composite scores.
#
# 5. Maximum drawdown significantly impacts fund rankings.
#
# 6. Alpha values show several funds generated excess returns.
#
# 7. Beta values indicate varying sensitivity to market movements.
#
# 8. Top funds achieved strong 3-year CAGR performance.
#
# 9. Risk-adjusted metrics provide better evaluation than raw returns.
#
# 10. Composite scorecard effectively identifies well-balanced funds.

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'alpha_beta.csv',
#  'amfi_validation.py',
#  'benchmark_comparison.png',
#  'bluestock_mf.db',
#  'cagr_table.csv',
#  'daily_return_distribution.png',
#  'dashboard',
#  'data',
#  'data_cleaning.py',
#  'data_ingestion.py',
#  'EDA_Analysis.ipynb',
#  'FULL_PATH_TO_DATABASE',
#  'fund_scorecard.csv',
#  'fund_scorecard.png',
#  'live_nav_fetch.py',
#  'load_to_sqlite.py',
#  'mf-analytics',
#  'mutual_funds.db',
#  'notebooks',
#  'Performance_Analytics.ipynb',
#  'reports',
#  'requirements.txt',
#  'sharpe_ratio_rankings.csv',
#  'sortino_ratio_rankings.csv',
#  'sql',
#  'Untitled.ipynb']
